# %% [markdown]
# # **Homework 1: COVID-19 Cases Prediction (Regression)**

# %% [markdown]
# Author: Heng-Jui Chang
#
# Slides: https://github.com/ga642381/ML2021-Spring/blob/main/HW01/HW01.pdf
# Video: TBA
#
# Objectives:
# * Solve a regression problem with deep neural networks (DNN).
# * Understand basic DNN training tips.
# * Get familiar with PyTorch.
#
# If any questions, please contact the TAs via TA hours, NTU COOL, or email.

# %% [markdown]
# # **Download Data**
#
#
# If the Google drive links are dead, you can download data from [kaggle](https://www.kaggle.com/c/ml2021spring-hw1/data), and upload data manually to the workspace.

# %%
tr_path = 'covid.train.csv'  # path to training data
tt_path = 'covid.test.csv'   # path to testing data

# !gdown --id '19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF' --output covid.train.csv
# !gdown --id '1CE240jLm2npU-tdz81-oVKEF3T2yfT1O' --output covid.test.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF
# To: /content/covid.train.csv
# 100% 2.00M/2.00M [00:00<00:00, 61.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CE240jLm2npU-tdz81-oVKEF3T2yfT1O
# To: /content/covid.test.csv
# 100% 651k/651k [00:00<00:00, 93.6MB/s]

# %% [markdown]
# # **Import Some Packages**

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 42069  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# # **Some Utilities**
#
# You do not need to modify this part.

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()


def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# # **Preprocess**
#
# We have three kinds of datasets:
# * `train`: for training
# * `dev`: for validation
# * `test`: for testing (w/o target value)

# %% [markdown]
# ## **Dataset**
#
# The `COVID19Dataset` below does:
# * read `.csv` files
# * extract features
# * split `covid.train.csv` into train/dev sets
# * normalize features
#
# Finishing `TODO` below might make you pass medium baseline.

# %%
class COVID19Dataset(Dataset):
    ''' Dataset for loading and preprocessing the COVID19 dataset '''
    def __init__(self,
                 path,
                 mode='train',
                 target_only=False):
        self.mode = mode

        # Read data into numpy arrays
        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)
        
        if not target_only:
            feats = list(range(93))
        else:
            # Use the features with higher MI score
            feats = [57] + [75] + [78] + [60] + [42] + [79] + [61] + [43] \
             + [77] + [59] + [41] + [58] + [76] + [40]

        if mode == 'test':
            # Testing data
            # data: 893 x 93 (40 states + day 1 (18) + day 2 (18) + day 3 (17))
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training data (train/dev sets)
            # data: 2700 x 94 (40 states + day 1 (18) + day 2 (18) + day 3 (18))
            target = data[:, -1]
            data = data[:, feats]
            
            # Splitting training data into train & dev sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing (no target)
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %%
# Feature Selection
# Reference: https://www.kaggle.com/ryanholbrook/mutual-information
import numpy as np
import pandas as pd
import seaborn as sns

plt.style.use("seaborn-whitegrid")

df = pd.read_csv("covid.train.csv")
df.head()

X = df.copy()
y = X.pop("tested_positive.2")


from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y):
    mi_scores = mutual_info_regression(X, y)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y)
mi_scores[::3]  # show a few features with their MI scores

def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 15))
plot_mi_scores(mi_scores)

# %% [markdown]
# From the MI scores, we know that "tested_positive", "hh_cmnty_cli","nohh_cmnty_cli", "ili" and "cli" are the most important features to predict "tested_positive.2". Thus, we will inlcude them (3-day data) in the model.

# %% [markdown]
# ## **DataLoader**
#
# A `DataLoader` loads data from a given `Dataset` into batches.

# %%
def prep_dataloader(path, mode, batch_size, n_jobs=0, target_only=False):
    ''' Generates a dataset, then is put into a dataloader. '''
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)  # Construct dataset
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)                            # Construct dataloader
    return dataloader

# %% [markdown]
# # **Deep Neural Network**
#
# `NeuralNet` is an `nn.Module` designed for regression.
# The DNN consists of 2 fully-connected layers with ReLU activation.
# This module also included a function `cal_loss` for calculating loss.

# %%
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()

        # Define your neural network here
        # TODO: How to modify this model to achieve better performance?
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        # Mean squared error loss
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        # Implement L2 regularization here
        l2_penalty = 0
        #for p in self.parameters():
        #  l2_penalty = p.norm(2) ** 2
        return self.criterion(pred, target)
        # return self.criterion(pred, target) + 0.1 * l2_penalty

# %% [markdown]
# # **Train/Dev/Test**

# %% [markdown]
# ## **Training**

# %%
def train(tr_set, dv_set, model, config, device):
    ''' DNN training '''

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        # After each epoch, test your model on the validation (development) set.
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            # Stop training if your model stops improving for "config['early_stop']" epochs.
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# ## **Validation**

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# ## **Testing**

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# # **Setup Hyper-parameters**
#
# `config` contains hyper-parameters for training and the path to save your model.

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
target_only = True                  # TODO: Using 40 states & 2 tested_positive features

# Strategy: small batch size, small learning rate
config = {
    'n_epochs': 5000,                # maximum number of epochs
    'batch_size': 45,               # mini-batch size for dataloader
    'optimizer': 'Adam',              # optimization algorithm (optimizer in torch.optim)
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        'lr': 0.0001,              # learning rate of SGD
        'betas': (0.9, 0.999),
        'eps': 1e-08,
        'weight_decay': 0,
        'amsgrad': False 
    },
    'early_stop': 200,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %% [markdown]
# # **Load data and model**

# %%
tr_set = prep_dataloader(tr_path, 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataloader(tr_path, 'dev', config['batch_size'], target_only=target_only)
tt_set = prep_dataloader(tt_path, 'test', config['batch_size'], target_only=target_only)
# Out:
# Finished reading the train set of COVID19 Dataset (2430 samples found, each dim = 14)
# Finished reading the dev set of COVID19 Dataset (270 samples found, each dim = 14)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 14)

# %%
model = NeuralNet(tr_set.dataset.dim).to(device)  # Construct model and move to device

# %% [markdown]
# # **Start Training!**

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 52.9569)
# Saving model (epoch =    2, loss = 24.3382)
# Saving model (epoch =    3, loss = 13.0171)
# Saving model (epoch =    4, loss = 9.4125)
# Saving model (epoch =    5, loss = 8.2243)
# Saving model (epoch =    6, loss = 7.5342)
# Saving model (epoch =    7, loss = 6.9906)
# Saving model (epoch =    8, loss = 6.5102)
# Saving model (epoch =    9, loss = 6.0724)
# Saving model (epoch =   10, loss = 5.6564)
# Saving model (epoch =   11, loss = 5.2728)
# Saving model (epoch =   12, loss = 4.8982)
# Saving model (epoch =   13, loss = 4.5445)
# Saving model (epoch =   14, loss = 4.2317)
# Saving model (epoch =   15, loss = 3.9093)
# Saving model (epoch =   16, loss = 3.6126)
# Saving model (epoch =   17, loss = 3.3425)
# Saving model (epoch =   18, loss = 3.0894)
# Saving model (epoch =   19, loss = 2.8745)
# Saving model (epoch =   20, loss = 2.6556)
# Saving model (epoch =   21, loss = 2.4577)
# Saving model (epoch =   22, loss = 2.2869)
# Saving model (epoch =   23, loss = 2.1652)
# Saving model (epoch =   24, loss = 1.9992)
# Saving model (epoch =   25, loss = 1.8963)
# Saving model (epoch =   26, loss = 1.7738)
# Saving model (epoch =   27, loss = 1.6869)
# Saving model (epoch =   28, loss = 1.6117)
# Saving model (epoch =   29, loss = 1.5535)
# Saving model (epoch =   30, loss = 1.4904)
# Saving model (epoch =   31, loss = 1.4527)
# Saving model (epoch =   32, loss = 1.4146)
# Saving model (epoch =   33, loss = 1.3838)
# Saving model (epoch =   34, loss = 1.3796)
# Saving model (epoch =   35, loss = 1.3359)
# Saving model (epoch =   37, loss = 1.3134)
# Saving model (epoch =   38, loss = 1.3008)
# Saving model (epoch =   39, loss = 1.2678)
# Saving model (epoch =   40, loss = 1.2593)
# Saving model (epoch =   42, loss = 1.2525)
# Saving model (epoch =   43, loss = 1.2409)
# Saving model (epoch =   47, loss = 1.2327)
# Saving model (epoch =   49, loss = 1.2208)
# Saving model (epoch =   54, loss = 1.2055)
# Saving model (epoch =   55, loss = 1.2046)
# Saving model (epoch =   57, loss = 1.1975)
# Saving model (epoch =   62, loss = 1.1919)
# Saving model (epoch =   63, loss = 1.1841)
# Saving model (epoch =   65, loss = 1.1799)
# Saving model (epoch =   67, loss = 1.1756)
# Saving model (epoch =   70, loss = 1.1682)
# Saving model (epoch =   72, loss = 1.1646)
# Saving model (epoch =   73, loss = 1.1612)
# Saving model (epoch =   76, loss = 1.1548)
# Saving model (epoch =   77, loss = 1.1534)
# Saving model (epoch =   78, loss = 1.1505)
# Saving model (epoch =   80, loss = 1.1492)
# Saving model (epoch =   81, loss = 1.1447)
# Saving model (epoch =   82, loss = 1.1419)
# Saving model (epoch =   84, loss = 1.1419)
# Saving model (epoch =   85, loss = 1.1366)
# Saving model (epoch =   87, loss = 1.1307)
# Saving model (epoch =   90, loss = 1.1097)
# Saving model (epoch =   95, loss = 1.0989)
# Saving model (epoch =   96, loss = 1.0982)
# Saving model (epoch =   97, loss = 1.0964)
# Saving model (epoch =   98, loss = 1.0927)
# Saving model (epoch =  100, loss = 1.0894)
# Saving model (epoch =  103, loss = 1.0836)
# Saving model (epoch =  104, loss = 1.0819)
# Saving model (epoch =  105, loss = 1.0783)
# Saving model (epoch =  109, loss = 1.0709)
# Saving model (epoch =  111, loss = 1.0665)
# Saving model (epoch =  112, loss = 1.0650)
# Saving model (epoch =  120, loss = 1.0521)
# Saving model (epoch =  121, loss = 1.0480)
# Saving model (epoch =  124, loss = 1.0425)
# Saving model (epoch =  126, loss = 1.0386)
# Saving model (epoch =  128, loss = 1.0336)
# Saving model (epoch =  129, loss = 1.0317)
# Saving model (epoch =  131, loss = 1.0316)
# Saving model (epoch =  132, loss = 1.0281)
# Saving model (epoch =  134, loss = 1.0222)
# Saving model (epoch =  135, loss = 1.0213)
# Saving model (epoch =  137, loss = 1.0167)
# Saving model (epoch =  138, loss = 1.0152)
# Saving model (epoch =  145, loss = 1.0054)
# Saving model (epoch =  146, loss = 0.9990)
# Saving model (epoch =  148, loss = 0.9977)
# Saving model (epoch =  150, loss = 0.9914)
# Saving model (epoch =  151, loss = 0.9896)
# Saving model (epoch =  156, loss = 0.9882)
# Saving model (epoch =  158, loss = 0.9822)
# Saving model (epoch =  160, loss = 0.9777)
# Saving model (epoch =  162, loss = 0.9711)
# Saving model (epoch =  168, loss = 0.9627)
# Saving model (epoch =  171, loss = 0.9578)
# Saving model (epoch =  174, loss = 0.9533)
# Saving model (epoch =  176, loss = 0.9506)
# Saving model (epoch =  177, loss = 0.9505)
# Saving model (epoch =  178, loss = 0.9476)
# Saving model (epoch =  181, loss = 0.9452)
# Saving model (epoch =  184, loss = 0.9397)
# Saving model (epoch =  187, loss = 0.9360)
# Saving model (epoch =  191, loss = 0.9306)
# Saving model (epoch =  193, loss = 0.9279)
# Saving model (epoch =  195, loss = 0.9255)
# Saving model (epoch =  198, loss = 0.9225)
# Saving model (epoch =  199, loss = 0.9207)
# Saving model (epoch =  200, loss = 0.9193)
# Saving model (epoch =  206, loss = 0.9128)
# Saving model (epoch =  208, loss = 0.9110)
# Saving model (epoch =  209, loss = 0.9094)
# Saving model (epoch =  210, loss = 0.9083)
# Saving model (epoch =  214, loss = 0.9044)
# Saving model (epoch =  218, loss = 0.8998)
# Saving model (epoch =  220, loss = 0.8979)
# Saving model (epoch =  221, loss = 0.8976)
# Saving model (epoch =  222, loss = 0.8959)
# Saving model (epoch =  227, loss = 0.8919)
# Saving model (epoch =  232, loss = 0.8863)
# Saving model (epoch =  234, loss = 0.8849)
# Saving model (epoch =  239, loss = 0.8842)
# Saving model (epoch =  243, loss = 0.8771)
# Saving model (epoch =  245, loss = 0.8752)
# Saving model (epoch =  246, loss = 0.8743)
# Saving model (epoch =  248, loss = 0.8739)
# Saving model (epoch =  250, loss = 0.8714)
# Saving model (epoch =  253, loss = 0.8690)
# Saving model (epoch =  254, loss = 0.8688)
# Saving model (epoch =  260, loss = 0.8636)
# Saving model (epoch =  261, loss = 0.8629)
# Saving model (epoch =  267, loss = 0.8589)
# Saving model (epoch =  272, loss = 0.8579)
# Saving model (epoch =  273, loss = 0.8557)
# Saving model (epoch =  283, loss = 0.8515)
# Saving model (epoch =  284, loss = 0.8488)
# Saving model (epoch =  285, loss = 0.8478)
# Saving model (epoch =  288, loss = 0.8462)
# Saving model (epoch =  294, loss = 0.8439)
# Saving model (epoch =  298, loss = 0.8428)
# Saving model (epoch =  299, loss = 0.8408)
# Saving model (epoch =  302, loss = 0.8387)
# Saving model (epoch =  303, loss = 0.8380)
# Saving model (epoch =  309, loss = 0.8351)
# Saving model (epoch =  314, loss = 0.8332)
# Saving model (epoch =  315, loss = 0.8332)
# Saving model (epoch =  320, loss = 0.8307)
# Saving model (epoch =  322, loss = 0.8295)
# Saving model (epoch =  325, loss = 0.8287)
# Saving model (epoch =  327, loss = 0.8270)
# Saving model (epoch =  329, loss = 0.8266)
# Saving model (epoch =  330, loss = 0.8261)
# Saving model (epoch =  332, loss = 0.8252)
# Saving model (epoch =  335, loss = 0.8244)
# Saving model (epoch =  339, loss = 0.8243)
# Saving model (epoch =  340, loss = 0.8232)
# Saving model (epoch =  343, loss = 0.8217)
# Saving model (epoch =  345, loss = 0.8208)
# Saving model (epoch =  348, loss = 0.8206)
# Saving model (epoch =  349, loss = 0.8192)
# Saving model (epoch =  355, loss = 0.8182)
# Saving model (epoch =  359, loss = 0.8171)
# Saving model (epoch =  363, loss = 0.8169)
# Saving model (epoch =  371, loss = 0.8164)
# Saving model (epoch =  372, loss = 0.8129)
# Saving model (epoch =  381, loss = 0.8118)
# Saving model (epoch =  383, loss = 0.8107)
# Saving model (epoch =  393, loss = 0.8082)
# Saving model (epoch =  397, loss = 0.8070)
# Saving model (epoch =  402, loss = 0.8056)
# Saving model (epoch =  404, loss = 0.8055)
# Saving model (epoch =  405, loss = 0.8054)
# Saving model (epoch =  408, loss = 0.8047)
# Saving model (epoch =  421, loss = 0.8038)
# Saving model (epoch =  422, loss = 0.8027)
# Saving model (epoch =  423, loss = 0.8024)
# Saving model (epoch =  434, loss = 0.8010)
# Saving model (epoch =  454, loss = 0.7985)
# Saving model (epoch =  457, loss = 0.7981)
# Saving model (epoch =  465, loss = 0.7971)
# Saving model (epoch =  473, loss = 0.7969)
# Saving model (epoch =  477, loss = 0.7955)
# Saving model (epoch =  484, loss = 0.7950)
# Saving model (epoch =  488, loss = 0.7945)
# Saving model (epoch =  495, loss = 0.7943)
# Saving model (epoch =  498, loss = 0.7935)
# Saving model (epoch =  521, loss = 0.7933)
# Saving model (epoch =  523, loss = 0.7915)
# Saving model (epoch =  526, loss = 0.7909)
# Saving model (epoch =  544, loss = 0.7905)
# Saving model (epoch =  549, loss = 0.7892)
# Saving model (epoch =  550, loss = 0.7890)
# Saving model (epoch =  559, loss = 0.7889)
# Saving model (epoch =  568, loss = 0.7885)
# Saving model (epoch =  574, loss = 0.7877)
# Saving model (epoch =  592, loss = 0.7874)
# Saving model (epoch =  596, loss = 0.7868)
# Saving model (epoch =  597, loss = 0.7866)
# Saving model (epoch =  611, loss = 0.7858)
# Saving model (epoch =  648, loss = 0.7849)
# Saving model (epoch =  649, loss = 0.7848)
# Saving model (epoch =  657, loss = 0.7844)
# Saving model (epoch =  662, loss = 0.7841)
# Saving model (epoch =  688, loss = 0.7835)
# Saving model (epoch =  697, loss = 0.7833)
# Saving model (epoch =  702, loss = 0.7830)
# Saving model (epoch =  721, loss = 0.7826)
# Saving model (epoch =  724, loss = 0.7821)
# Saving model (epoch =  741, loss = 0.7819)
# Saving model (epoch =  760, loss = 0.7814)
# Saving model (epoch =  777, loss = 0.7811)
# Saving model (epoch =  797, loss = 0.7804)
# Saving model (epoch =  809, loss = 0.7799)
# Saving model (epoch =  833, loss = 0.7798)
# Saving model (epoch =  835, loss = 0.7797)
# Saving model (epoch =  841, loss = 0.7795)
# Saving model (epoch =  847, loss = 0.7794)
# Saving model (epoch =  869, loss = 0.7789)
# Saving model (epoch =  878, loss = 0.7787)
# Saving model (epoch =  948, loss = 0.7785)
# Saving model (epoch =  951, loss = 0.7785)
# Saving model (epoch =  963, loss = 0.7774)
# Saving model (epoch =  969, loss = 0.7774)
# Saving model (epoch =  989, loss = 0.7773)
# Saving model (epoch = 1006, loss = 0.7769)
# Saving model (epoch = 1008, loss = 0.7768)
# Saving model (epoch = 1013, loss = 0.7766)
# Saving model (epoch = 1038, loss = 0.7765)
# Saving model (epoch = 1080, loss = 0.7764)
# Saving model (epoch = 1096, loss = 0.7764)
# Saving model (epoch = 1099, loss = 0.7761)
# Saving model (epoch = 1114, loss = 0.7756)
# Saving model (epoch = 1157, loss = 0.7755)
# Saving model (epoch = 1174, loss = 0.7751)
# Saving model (epoch = 1239, loss = 0.7748)
# Saving model (epoch = 1328, loss = 0.7746)
# Saving model (epoch = 1330, loss = 0.7744)
# Saving model (epoch = 1345, loss = 0.7740)
# Saving model (epoch = 1368, loss = 0.7740)
# Saving model (epoch = 1456, loss = 0.7739)
# Saving model (epoch = 1494, loss = 0.7738)
# Saving model (epoch = 1621, loss = 0.7736)
# Finished training after 1822 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)  # Show prediction on the validation set

# %% [markdown]
# # **Testing**
# The predictions of your model on testing set will be stored at `pred.csv`.

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'pred.csv')         # save prediction file to pred.csv
# Out:
# Saving results to pred.csv

# %% [markdown]
# # **Hints**
#
# ## **Simple Baseline**
# * Run sample code
#
# ## **Medium Baseline**
# * Feature selection: 40 states + 2 `tested_positive` (`TODO` in dataset)
#
# ## **Strong Baseline**
# * Feature selection (what other features are useful?)
# * DNN architecture (layers? dimension? activation function?)
# * Training (mini-batch? optimizer? learning rate?)
# * L2 regularization
# * There are some mistakes in the sample code, can you find them?

# %% [markdown]
# # **Reference**
# This code is completely written by Heng-Jui Chang @ NTUEE.
# Copying or reusing this code is required to specify the original author.
#
# Source:
# 1. Heng-Jui Chang @ NTUEE (https://github.com/ga642381/ML2021-Spring/blob/main/HW01/HW01.ipynb)
# 2. https://www.kaggle.com/ryanholbrook/mutual-information
